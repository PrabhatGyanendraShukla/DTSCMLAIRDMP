# %% [markdown]
# <a href="https://colab.research.google.com/github/PrabhatGyanendraShukla/DTSCMLAIRDMP/blob/main/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# GitHub API: Fetch info about a GitHub user
username = "octocat"
url = f"https://api.github.com/users/{username}"

response = requests.get(url)
data = response.json()

print("GitHub User:", data["login"])
print("Public Repos:", data["public_repos"])
print("Followers:", data["followers"])
print("Profile URL:", data["html_url"])
# Out:
# GitHub User: octocat
# Public Repos: 8
# Followers: 20393
# Profile URL: https://github.com/octocat

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Verify Kaggle setup
# !kaggle datasets list -s "fraud"
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 4, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/__init__.py", line 6, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 434, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
import json
with open('kaggle.json') as f:
    print(json.load(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1326021756.py in <cell line: 0>()
#       1 import json
# ----> 2 with open('kaggle.json') as f:
#       3     print(json.load(f))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kaggle.json'

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Test
# !kaggle datasets list -s "fraud"
# Out:
# ref                                                         title                                                   size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  ------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# mlg-ulb/creditcardfraud                                     Credit Card Fraud Detection                         69155672  2018-03-23 01:17:27.913000        1019247      12575  0.85294116
# whenamancodes/fraud-detection                               Fraud Detection                                     69155672  2022-09-12 11:54:40.550000          11431        123  1.0
# dhanushnarayananr/credit-card-fraud                         Credit Card Fraud                                   30281243  2022-05-07 15:09:29.617000          29168        221  0.9411765
# ...

# %%
# !kaggle datasets list -s "fraud"
# Out:
# ref                                                         title                                                   size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  ------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# mlg-ulb/creditcardfraud                                     Credit Card Fraud Detection                         69155672  2018-03-23 01:17:27.913000        1019251      12575  0.85294116
# whenamancodes/fraud-detection                               Fraud Detection                                     69155672  2022-09-12 11:54:40.550000          11431        123  1.0
# dhanushnarayananr/credit-card-fraud                         Credit Card Fraud                                   30281243  2022-05-07 15:09:29.617000          29168        221  0.9411765
# ...

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#   0% 0.00/66.0M [00:00<?, ?B/s]
# 100% 66.0M/66.0M [00:00<00:00, 1.37GB/s]

# %%
# !unzip creditcardfraud.zip
# Out:
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
import pandas as pd

df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...
